# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tabulate import tabulate

# %%
dfQ32024 = pd.read_csv('Copy of RD&D Scorecard Feedback 2023-2024 Raw Data - Q3 - 2024.csv')
dfQ32024
# Out:
#          Candidate Name                                    Job  \
# 0          Pedro Zenone            Senior Data Scientist LATAM
# 1    Joaquin Tempelsman            Senior Data Scientist LATAM
# 2          Gastón Ortiz            Senior Data Scientist LATAM
# 3         Malena Maffei            Senior Data Scientist LATAM
# 4        Matías Miranda            Senior Data Scientist LATAM
# ..                  ...                                    ...
# 348      Darwis Narvaez  Software Engineer (Integrity) - LATAM
# 349  Joaquin Tempelsman            Senior Data Scientist LATAM
# 350      Santiago Amena            Senior Data Scientist LATAM
# 351        Gastón Ortiz            Senior Data Scientist LATAM
# 352       Malena Maffei            Senior Data Scientist LATAM
#
#                                Requisition ID Department Current Status  \
# 0    Evergreen  - Senior Data Scientist LATAM       Data       Rejected
# ...

# %%
dfq42023 = pd.read_csv('Copy of RD&D Scorecard Feedback 2023-2024 Raw Data - Q4 - 2023.csv')
dfq42023
# Out:
#                    Candidate Name  \
# 0                Federico Aballay
# 1                    Ali Ahmadian
# 2                Gonzalo Albornoz
# 3    Maria Camila Aldana Guerrero
# 4               Matias Altamirano
# ..                            ...
# 158             Sebastian Virguez
# 159                Javier Waitzel
# 160              Maximiliano Ward
# 161                 Petr Ziuzikov
# 162                 Petr Ziuzikov
#
#                                               Job  \
# 0                      Senior Data Engineer LATAM
# 1            Senior iOS Engineer (Mobile) - LATAM
# 2    Senior Staff Machine Learning Engineer LATAM
# 3    Senior Business Intelligence Analyst (LatAm)
# 4                      Senior Data Engineer LATAM
# ..                                            ...
# 158  Senior Business Intelligence Analyst (LatAm)
# 159          Senior iOS Engineer (Mobile) - LATAM
# 160          Senior iOS Engineer (Mobile) - LATAM
# ...

# %%
# Plotting the barplot with count of interviews
barplot = df_percentages.plot(x='Quarter', y='Count', kind='bar', legend=False, color=['#4B8BBE', '#306998'])
barplot.set_title('Count of Interviews Conducted')
barplot.set_xlabel('Quarter')
barplot.set_ylabel('Count')

# Adding labels on top of each bar
for p in barplot.patches:
    barplot.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))

# Improving the style
plt.xticks(rotation=0)
plt.grid(False)  # Remove grid lines
plt.tight_layout()

# Display the plot
plt.show()
